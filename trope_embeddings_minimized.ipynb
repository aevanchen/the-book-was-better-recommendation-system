# %%
import gensim
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
import itertools
import json
import pickle
from nltk.tokenize import word_tokenize
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')

# %%
'''
Load a json file into a dictionary

Input: 
    - file_path: path to json file containing dataset

Returns: 
    - 
'''
def load_json(file_path): 
    with open(file_path, 'r') as f: 
        data = json.load(f)
    return data

# %%
'''
Returns the k tropes closest to the keyword 

Inputs: 
    - keyword: the keyword to search
    - word_to_trope: dictionary mapping word to set of tropes containing the word
    - model: the pretrained gensim model
    - top_k: number of tropes to return

Returns: 
    - trope_matches: list of the k tropes that are closest to the keyword
'''
def get_closest_tropes_to_keyword(keyword, word_to_trope, model, top_k = 5): 
    
    # check that keyword is in vocabulary 
    if keyword in model.vocab: 
        # compute cosine similarity between query and all trope words
        all_words = list(word_to_trope.keys())
        all_words = [word for word in all_words if word in model.vocab]
        dists = model.distances(keyword, all_words)

        # sort by similarity in ascending order (0 = perfect similarity)
        sorted_indices = np.argsort(dists)
        sorted_keyword_match = [all_words[idx] for idx in sorted_indices[:top_k]]

        print('\ntop {} matches most similar to `{}`'.format(top_k, keyword))
        for word in sorted_keyword_match: 
            print('`{}` : {}'.format(word, word_to_trope[word]))

        trope_matches = list(itertools.chain.from_iterable([word_to_trope[word] for word in sorted_keyword_match if word in word_to_trope]))
        print('\nenhancing search with : {}'.format(trope_matches[:top_k]))

        return trope_matches[:top_k]
    
    else: 
        print('`{}` not in model vocabulary, cannot enhance search with keyword'.format(keyword))
        return []

# %%
'''
Finds the best titles according to tropes based on an input title and keyword. 
The trope words of the title being searched and the trope words most similar to 
the keyword are used to find the best matches. Half the number of the tropes corresponding
to the title being queried are used to enhance the keyword aspect of the search (eg. if the 
queried title has 10 tropes associated with it, then the top 5 tropes associated with the 
keyword will be used to enhance the search. This value seems to result in a good balance)

Inputs: 
    - title: the title being queried
    - from_dataset: the dataset corresponding to the title (eg. book dataset if book title)
    - keyword: the keyword to search
    - word_to_trope: dictionary mapping word to set of tropes containing the word
    - to_tf_idf_matrix: tf-idf representation of tropes associated with each title of desired return type
    - similarity_matrix: similarity matrix according to tf-idf representation 
    - model: the pretrained gensim model
    
Reutrns: 
    - similarity_scores: numpy array of similarity scores in where the index in the array corresponds
                         to the index in the dataset of the media type being recommended
'''
def best_titles_by_tropes_enhanced(title, from_dataset, keyword, word_to_trope, vectorizer, to_tf_idf_matrix, model): 
    
    # get tropes coresponding to title 
    title_tropes =  from_dataset[title]
    print('tropes for title `{}` : {}'.format(title, title_tropes))
    
    # get most similar tropes to keyword, use half the number of tropes in the title to enhance search 
    top_k_tropes = int(len(title_tropes)/2)
    most_similar_tropes = get_closest_tropes_to_keyword(keyword, word_to_trope, model, top_k_tropes)
    
    # extend query to include tropes associated with keyword
    query_tropes = most_similar_tropes + title_tropes
    
    print('\ntropes used for final query : {}'.format(query_tropes))
    
    # generate a query vector 
    query_vector = vectorizer.transform([' '.join(query_tropes)])
    
    # compute cosine similarity between query and all titles 
    similarity_scores = cosine_similarity(query_vector, to_tf_idf_matrix).flatten()
    
    return similarity_scores

# %%
def print_results(title, keyword, similarity_scores, to_dataset, top_k_titles = 10): 
    
    # sort the scores in descending order
    ranked_indices = np.argsort(similarity_scores)[::-1]
    
    # get list of titles
    to_titles = list(to_dataset.keys())

    print('\ntop {} most similar titles to `{}` by trope to keyword `{}` '.format(top_k_titles, title, keyword))
    for idx in range(top_k_titles): 
        print((similarity_scores[ranked_indices[idx]], to_titles[ranked_indices[idx]]))

# %%
# load small word embedding model
model = KeyedVectors.load("tbwb_model.bin")

# %%
# load book and movie datasets
books = load_json('Literature_tropes_dataset3.json')
movies = load_json('Film_tropes_dataset3.json')

# %%
# load word to trope mappings
book_word_to_trope = load_json('book_word_to_trope.json')
movie_word_to_trope = load_json('movie_word_to_trope.json')

# %%
# load vectorizers 
book_to_movie_vectorizer = pickle.load(open("book_to_movie_vectorizer.pickle", "rb" ))
movie_to_book_vectorizer = pickle.load(open("movie_to_book_vectorizer.pickle", "rb" ))

# %%
# load tf-idf matrices
movie_tf_idf = pickle.load(open("movie_tf_idf.pickle", "rb" ))
book_tf_idf = pickle.load(open("book_tf_idf.pickle", "rb" ))

# %%
'''
FULL SEARCH ALGORITHM TO USE IN FINAL PROJECT. This returns a numpy array of similarity scores
for a title + keyword query

Inputs: 
     - title: the title being queried
     - keyword: the keyword being queried
     - direction: either 'book to movie' or 'movie to book' 

Returns: 
     - similarity_scores: numpy array of similarity scores where the index in the array 
                          corresponds to the index in the 'to' dataset (ie. if the query
                          direction was book to movie, the indices would correspond to the 
                          indices in the movie tropes dataset)
'''
def full_search(title, keyword, direction):
    
    
    if direction == 'book to movie': 
        from_dataset = books
        to_dataset = movies
        word_to_trope = movie_word_to_trope
        vectorizer = book_to_movie_vectorizer
        to_tf_idf_matrix = movie_tf_idf
    else: # movie to book
        from_dataset = movies
        to_dataset = books
        word_to_trope = book_word_to_trope
        vectorizer = movie_to_book_vectorizer
        to_tf_idf_matrix = book_tf_idf
           
    similarity_scores = best_titles_by_tropes_enhanced(title, 
                                                       from_dataset, 
                                                       keyword, 
                                                       word_to_trope, 
                                                       vectorizer, 
                                                       to_tf_idf_matrix, 
                                                       model)
    
    print_results(title, keyword, similarity_scores, to_dataset, 10)

    return similarity_scores

# %%
# example query 
scores = full_search('Harry Potter and the Chamber of Secrets', 'zombies', 'book to movie')
# Out:
# tropes for title `Harry Potter and the Chamber of Secrets` : ['DoesThisRemindYouOfAnything', 'ForebodingFleeingFlock', 'ParentalBonus', 'MaliciousSlander', 'ForgottenPhlebotinum', 'WordOfGod', 'BecomingTheBoast', 'StealingTheCredit', 'EpicFail', 'CoolAndUnusualPunishment', 'EarlyBirdCameo', 'OurBugbearsAreScarier', 'Diary', 'RansackedRoom', 'BlankBook', 'FlyingCar', 'ContrivedCoincidence', 'Narm', 'ButtDialingMordor', 'HearingVoices', 'WhatMeasureIsANonHuman', 'EnslavedTongue', 'NotMeThisTime', 'INeverSaidItWasPoison', 'SpiderSwarm', 'Narcissist', 'RedHerring', 'BeastInTheMaze', 'DudeNotFunny', 'BigBrotherInstinct', 'ComicallyIneptHealing', 'HandOfGlory', 'IThoughtEveryoneCouldDoThat', 'BreakTheHaughty', 'BalefulPolymorph', 'ObliviousGuiltSlinging', 'MrFanservice', 'AllForNothing', 'HijackedByGanon', 'OhCrap', 'ThoroughlyMistakenIdentity', 'TheAllegedExpert', 'MonsterOfTheWeek', 'MilkyWhiteEyes', 'StarstruckSpeechless', 'StrongerWithAge', 'LaserGuidedKarma', 'WritersCannotDoMath', 'MindRape', 'LittleNo', 'DisproportionateRetribution', 'BuffySpeak', 'SneezeOfDoom', 'ThisIsGonnaSuck', 'BatScare', 'InvisibleWriting', 'InnocuouslyImportantEpisode', 'LovePotion', 'VillainWithGoodPublicity', 'MuggleBornOfMages', 'WreckedWeapon', 'CallingOutForNotCalling', 'ThirdPersonPerson', 'TheReasonYouSuckSpeech', 'WhoWouldBeStupidEnough', 'ChekhovsGunman', 'LetMeAtHim', 'MagicMisfire', 'CaughtWithYourPantsDown', 'OrificeEvacuation', 'TheDandy', 'DeadlyBook', 'HilarityEnsues', 'SentientVehicle', 'HorrorDoesntSettleForSimpleTuesday', 'TrickedIntoSigning', 'EverybodyLives', 'HoistByHisOwnPetard', 'SignificantAnagram', 'NoodleIncident', 'RuleOfThree', 'ObfuscatingStupidity', 'JerkassHasAPoint', 'IJustWantToBeFree', 'SoulJar', 'AbsurdlySpaciousSewer', 'RewatchBonus', 'WroteTheBook', 'TomTheDarkLord', 'ShrineToSelf', 'AntiVillain', 'IHaveJustOneThingToSay', 'Irony', 'DeaderThanDead', 'DragonInChief', 'WellIntentionedExtremist', 'AbusiveParents', 'EatingOptional', 'SeriesContinuityError', 'AnAesop', 'WondrousLadiesRoom', 'AlternateIdentityAmnesia', 'XanatosGambit', 'CameraFiend', 'TheDragon', 'BlastingItOutOfTheirHands', 'ReptilesAreAbhorrent', 'WeaksauceWeakness', 'BackwardsFiringGun', 'MindControl', 'CoveringForTheNoise', 'DisappointedInYou', 'Lampshaded', 'PredecessorVillain', 'ArcVillain', 'ItIsDehumanizing', 'WhamLine', 'DarkerAndEdgier', 'NiceJobFixingItVillain', 'AdultFear', 'ArtisticLicenseBiology', 'DisneyDeath', 'KidsDrivingCars', 'EurekaMoment', 'HammyHerald', 'CerebusSyndrome', 'GreaterScopeVillain', 'SpinningOutOfHere', 'EyeScream', 'DoWrongRight', 'PostMortemComeback', 'YouAreBetterThanYouThinkYouAre', 'PensieveFlashback', 'ClownCar', 'WontTakeYesForAnAnswer', 'JokeAndReceive', 'RightBehindMe', 'BeCarefulWhatYouWishFor', 'UnwantedAssistance', 'BrickJoke', 'BasiliskAndCockatrice', 'Foreshadowing', 'LoopholeAbuse', 'DirtyCoward', 'DidntThinkThisThrough', 'FailedASpotCheck', 'BathroomStallOfOverheardInsults', 'BigBad', 'CoverIdentityAnomaly', 'MissedTheBus', 'SavedByTheAwesome', 'INeverGotAnyLetters', 'HoldingItForAFriend', 'FacePalm', 'ShoutOut', 'HeelFaceTurn', 'MotiveMisidentification', 'SmallNameBigEgo', 'RightForTheWrongReasons', 'KnowNothingKnowItAll', 'GiantSpider', 'WatchOutForThatTree', 'AlliterativeTitle', 'GettingCrapPastTheRadar', 'PoliticallyIncorrectVillain', 'BodyHorror', 'AreYouSureYouCanDriveThisThing', 'INeedToGoIronMyDog', 'RealityEnsues', 'DeadAnimalWarning', 'PunnyName', 'NoConservationOfEnergy', 'ShrinkingViolet', 'DeadGuyJunior', 'InformedAbility', 'LeeroyJenkins', 'FeetOfClay', 'DangerousDeviceDisposalDebacle', 'GambitRoulette', 'TemptingFate', 'MailerDaemon', 'PortalSlam', 'ItsLikeIAlwaysSay', 'WhyDidItHaveToBeSnakes', 'HarmfulHealing', 'HeadlockOfDominance', 'StalkerWithACrush', 'SealedEvilInACan', 'ForgottenBirthday', 'ActuallyPrettyFunny', 'SwordCane', 'IneptMage', 'SerpentOfImmortality', 'EarlyInstallmentWeirdness', 'EasilyCondemned', 'LivingMemory', 'AscendedExtra', 'FollowTheWhiteRabbit', 'DinnerWithTheBoss',  ...
#
# top 101 matches most similar to `zombies`
# `zombies` : ['NaziZombies', 'RoomFullOfZombies', 'EverythingsDeaderWithZombies', 'OurZombiesAreDifferent']
# `zombie` : ['NoZombieCannibals', 'ZombieAdvocate', 'ZombieMooks', 'PlagueZombie', 'NinjaPirateZombieRobot', 'VoodooZombie', 'ArtificialZombie', 'NotAZombie', 'NinjaPirateRobotZombie', 'IncongruouslyDressedZombie', 'ZombieGait', 'TechnicallyLivingZombie', 'RevenantZombie', 'ZombieApocalypse', 'ZombiePukeAttack', 'ReviveKillsZombie', 'AndThenJohnWasAZombie', 'ZombieInfectee', 'AttractiveZombie', 'FriendlyZombie']
# `vampires` : ['FriendlyNeighborhoodVampires', 'VampiresSleepInCoffins', 'VampiresOwnNightclubs', 'VampiresHarem', 'YourVampiresSuck', 'VampiresAreRich', 'OurVampiresAreDifferent', 'VampiresOwnNightClubs', 'VampiresHateGarlic', 'VampiresAreSexGods', 'FriendlyNeighbourhoodVampires']
# `undead` : ['UndeadAuthor', 'TheUndead', 'UndeadChild', 'TurnUndead', 'UndeadTaxExemption', 'MistakenForUndead', 'UndeadBarefooter', 'BurnTheUndead', 'SlidingScaleOfUndeadRegeneration']
# `monsters` : ['AliensAndMonsters', 'HunterOfMonsters', 'LetsMockTheMonsters', 'OurMonstersAreWeird', 'MonstersAnonymous', 'MonogenderMonsters', 'InvisibleMonsters', 'OurMonstersAreDifferent', 'TheManBehindTheMonsters', 'HumansAreTheRealMonsters', 'BenevolentMonsters', 'TeensAreMonsters', 'HeWhoFightsMonsters', 'MonstersFavoritePettingSpot']
# `ghosts` : ['WhisperingGhosts', 'OurGhostsAreDifferent', 'BewareOfHitchhikingGhosts']
# `superheroes` : ['SuperheroesWearTights', 'OurAncestorsAreSuperheroes', 'MovieSuperheroesWearBlack', 'AnimalSuperheroes', 'SuperheroesWearCapes']
# `mutants` : ['RadiationImmuneMutants', 'Mutants']
# `demons` : ['DivinelyAppearingDemons', 'OurDemonsAreDifferent', 'HornyDemons']
# `freaks` : ['BusesAreForFreaks', 'LonersAreFreaks']
# `cockroaches` : ['CockroachesWillRuleTheEarth']
# `beast` : ['MusicSoothesTheSavageBeast', 'BeastMan', 'BeastOfBattle', 'BlindAndTheBeast', 'NumberOfTheBeast', 'FedToTheBeast', 'BeastAndBeauty', 'BeautyToBeast', 'BeastFable', 'MarkOfTheBeast', 'ResistTheBeast', 'DireBeast', 'YouSexyBeast', 'TheBeastMaster', 'MultipleTailedBeast', 'BeastWithAHumanFace']
# `creatures` : ['BondCreatures', 'WoodlandCreatures', 'DisneyCreaturesOfTheFarce']
# `devour` : ['DevourTheDragon']
# `beasts` : ['KingOfBeasts']
# `villains` : ['PunchClockVillains', 'MakeWayForTheNewVillains', 'SensibleHeroesSkimpyVillains', 'HeroesActVillainsHinder', 'SuperHeroMovieVillainsDie', 'VillainsActHeroesReact', 'VillainsNeverLie', 'PoliteVillainsRudeHeroes', 'VillainsBlendInBetter', 'SuperheroMovieVillainsDie', 'SlidingScaleOfAntiVillains', 'ShabbyHeroesWellDressedVillains', 'VillainsOutShopping', 'VillainsWantMercy', 'VillainsDyingGrace']
# `critters` : ['MixAndMatchCritters', 'FearsomeCrittersOfAmericanFolklore', 'CryingCritters']
# `werewolf` : ['Werewolf', 'WerewolfThemeNaming', 'VampireWerewolfLoveTriangle', 'HumanToWerewolfFootprints']
# `demon` : ['FaceOfAnAngelMindOfADemon', 'DemonLordsAndArchdevils', 'FemaleAngelMaleDemon', 'DemonSlaying', 'NobleDemon', 'DemonHead', 'AngelFaceDemonFace', 'DemonOfHumanOrigin', 'AscendedDemon']
# `minions` : ['AdorableEvilMinions', 'EvilMinions', 'IControlMyMinionsThrough']
# `mutant` : ['MutantDraftBoard', 'Mutant', 'TeenageMutantNinjaTurtles', 'SlimeSnailsAndMutantTails']
# `vampire` : ['VoluntaryVampireVictim', 'VampireBitesSuck', 'VampireHunter', 'KissOfTheVampire', 'VampireWerewolfLoveTriangle', 'ReligiousVampire', 'LesbianVampire', 'ActuallyNotAVampire', 'ClassicalMovieVampire', 'VampireVannabe', 'SlidingScaleOfVampireFriendliness', 'VampireApocalypse', 'ILoveYouVampireSon', 'VampireMonarch', 'VampireWannabe', 'VampireMusicals', 'VegetarianVampire', 'VampireFiction', 'VampireRefugee', 'IHateYouVampireDad', 'VampireVords', 'VampireDance', 'DaywalkingVampire', 'ChineseVampire', 'RomanticVampireBoy', 'FriendlyNeighborhoodVampire']
# `worms` : ['PitifulWorms']
# `creature` : ['BigShadowLittleCreature', 'ClockworkCreature', 'SmallAnnoyingCreature', 'CreatureOfHabit', 'CreatureHunterOrganization', 'CartoonCreature']
# `demonic` : ['DemonicDummy', 'DemonicPossession', 'DemonicHeadShake', 'DemonicInvaders', 'DragonsAreDemonic']
# `devouring` : ['AllDevouringBlackHoleLoanSharks']
# `evil` : ['DetectEvil', 'MakeupIsEvil', 'BeingTorturedMakesYouEvil', 'NebulousEvilOrganisation', 'SealedEvilInADuel', 'ThisIsYourBrainOnEvil', 'PayEvilUntoEvil', 'EvilDuo', 'EvilGloating', 'SlowlySlippingIntoEvil', 'ObviouslyEvil', 'TheEvilGenius', 'GoodWeaponEvilWeapon', 'LaughablyEvil', 'EvilChancellor', 'ReligionOfEvil', 'AncientEvil', 'BetterLivingThroughEvil', 'StupidEvil', 'EvilIsBurningHot', 'GirlScoutsAreEvil', 'BalanceBetweenGoodAndEvil', 'EvilTowerOfOminousness', 'EvilOrphan', 'TreacheryIsASpecialKindOfEvil', 'EvilRunningGood', 'EvilIsHammy', 'EvilSlinks', 'EvilMatriarch', 'EvilJesuit', 'EvilPuppeteer', 'EvilMinions', 'EvilEvolves', 'AuctionOfEvil', 'EvilTaintedThePlace', 'GoodProstheticEvilProsthetic', 'UnEvilLaugh', 'EvilGenius', 'EvilPrince', 'NotEvilJustMisunderstood', 'EvilSmellsBad', 'EvilReactionary', 'EvenEvilCanBeLoved', 'TheGoodTheBadAndTheEvil', 'ForcedIntoEvil', 'EvilFeelsGood', 'EvilOverlord', 'SealedEvilInASixPack', 'InbredAndEvil', 'GoodLipsEvilJaws', 'SeeNoEvilHearNoEvil', 'MinionWithAnFInEvil', 'LoveMakesYouEvil', 'GoodColorsEvilColors', 'EvilCannotComprehendGood', 'SealedEvilInACan', 'SealedEvilInATeddyBear', 'EvilIsCool', 'EvilVirtues', 'EvilIsFunny', 'DeliverUsFromEvil', 'GoodCannotComprehendEvil', 'PragmaticEvil', 'EvilOverlooker', 'ChaosIsEvil', 'EvilOldFolks', 'GoodRunningEvil', 'EvilStatesOfAmerica', 'EvilDoppelganger', 'EvilScheme', 'EvilIsPetty', 'EvilLawyerJoke', 'DigitalPiracyIsEvil', 'AmbitionIsEvil', 'EvilHasStandards', 'EvilNephew', 'RedAndBlackAndEvilAllOver', 'IndustrializedEvil', 'WardensAreEvil', 'EvilIsDumb', 'EvilWeapon', 'BrainsEvilBrawnGood', 'GodOfEvil', 'EvilLaugh', 'BalanceOfGoodAndEvil', 'EvilCounterpart', 'EvilUncle', 'BeingEvilSucks', 'EvilHasABadSenseOfHumor', 'SuperPoweredEvilSide', 'LeakingCanOfEvil', 'EvilSoundsDeep', 'FauxAffablyEvil', 'EvilParentsWantGoodKids', 'CuteIsEvil', 'TooFunnyToBeEvil', 'DarkIsNotEvil', 'MayContainEvil', 'GoodRepublicEvilEmpire', 'GardenOfEvil', 'ExcessiveEvilEyeshadow', 'EvilIsNotWellLit', 'EvilStoleMyFaith', 'EvilPaysBetter', 'EvilDiva', 'AristocratsAreEvil', 'RapeIsaSpecialKindofEvil', 'EvilPoacher', 'TheEvilArmy', 'TheEvilEmpire', 'EvilMakeover', 'TokenEvilTeammate', 'AdorableEvilMinion', 'NebulousEvilOrganization', 'APupilOfMineUntilHeTurnedToEvil', 'ObliviouslyEvil', 'HerosEvilPredecessor', 'StandardEvilOrganizationSquad', 'FangsAreEvil', 'WhatIsEvil', 'ToCreateAPlaygroundForEvil', 'EvilAlbino', 'NewMediaAreEvil', 'AdorableEvilMinions', 'ExploringTheEvilLair', 'BeardofEvil', 'EvilIsSexy', 'EvilIsDeathlyCold', 'EvilPowerVacuum', 'EvilOrphanageLady', 'EvilISPetty', 'EvilMeScaresMe', 'EvilStepmother', 'ButNotTooEvil', 'EvilIsBigger', 'NecessaryEvil', 'FoodChainOfEvil', 'GodIsEvil', 'EvilMentor', 'SuperpoweredEvilSide', 'RivalTurnedEvil', 'GoodHurtsEvil', 'EqualOpportunityEvil', 'ThenLetMeBeEvil', 'EvilSorceress', 'EvilArmy', 'MagicIsEvil', 'EvilTeacher', 'EvilKnockoff', 'BeardOfEvil', 'ExcessiveEvilEyeShadow', 'AlwaysChaoticEvil', 'DarkIsEvil', 'EvilInc', 'BlackEyesOfEvil', 'EvilDetectingDog', 'ArmiesAreEvil', 'IfYoureSoEvilEatThisKitten', 'EvilHero', 'EvilWillFail', 'EvilPlan', 'EvilIsNotAToy', 'EvilChef', 'RegularlyScheduledEvil', 'EvilLuddite', 'EvilColonialist', 'GoodNeedsEvil', 'SortingAlgorithmOfEvil', 'EvilAllAlong', 'GoodEyesEvilEyes', 'EvilIsSterile', 'EvilVsEvil', 'EvilEyebrows', 'EvilBrit', 'FashionableEvil', 'SlaveryIsASpecialKindOfEvil', 'SwampsAreEvil', 'GoodTamingEvilTaming', 'EvilCostumeSwitch', 'EvilIsEasy', 'GoodScarsEvilScars', 'UltimateEvil', 'EvilElevator', 'EvenEvilHasStandards', 'EvilCanNotComprehendGood', 'EvilIsOneBigHappyFamily', 'TheEvilPrince', 'AsLongAsThereIsEvil', 'StandardEvilEmpireHierarchy', 'NecessarilyEvil', 'AllergicToEvil', 'FliesEqualsEvil', 'MakeUpIsEvil', 'EvilIsVisceral', 'EvilEyeshadow', 'EvilSoundsRaspy', 'EvilDebtCollector', 'PeerPressureMakesYouEvil', 'EunuchsAreEvil', 'EvilRedHead', 'GoodWingsEvilWings', 'PresidentEvil', 'EvilPhone', 'EvilVersusEvil', 'NewTechnologyIsEvil', 'EvilSorcerer', 'Am ...
# `morph` : ['MorphWeapon']
# `spiders` : ['GiantSpiders', 'SpidersAreScary']
# `monster` : ['CagedInsideAMonster', 'MonsterFacade', 'MirrorMonster', 'MonsterOfTheWeek', 'HaveYouTriedNotBeingAMonster', 'YouMonster', 'RockMonster', 'SupportingTheMonsterLovedOne', 'MonsterIsAMommy', 'MonsterRoommate', 'ForgotToFeedTheMonster', 'MonsterModesty', 'LivingStructureMonster', 'MonsterMisogyny', 'TalkingTheMonsterToDeath', 'MonsterMash', 'MonsterDelay', 'MonsterOfTheAesop', 'NonMaliciousMonster', 'AntlionMonster', 'MuggingTheMonster', 'HybridMonster', 'MonsterMunch', 'AttackOfTheMonsterAppendage', 'BlobMonster', 'MetamorphosisMonster', 'WhackAMonster', 'MonsterFangirl', 'TrappedWithMonsterPlot', 'WrestlingMonster', 'GreenEyedMonster', 'AsteroidsMonster', 'MonsterClown', 'IAmAMonster', 'MonsterLord', 'ChestMonster', 'TorturedMonster', 'RetiredMonster', 'MagicIsAMonsterMagnet', 'FaceMonsterTurn', 'MonsterHunter', 'FemaleMonsterSurprise', 'FrankensteinsMonster', 'TragicMonster', 'LoweredMonsterDifficulty', 'MonsterShapedMountain', 'PerpetualMotionMonster', 'MechanicalMonster', 'PrehistoricMonster', 'CuteMonsterGirl', 'MainliningTheMonster', 'SeaMonster', 'ReluctantMonster', 'TouchOfTheMonster', 'MonsterSobStory', 'MonsterProgenitor', 'MonsterFromBeyondTheVeil', 'MiracleGroMonster', 'StockNessMonster', 'BrainMonster', 'MuckMonster', 'MonsterCloset', 'MakeMyMonsterGrow', 'MonsterProtectionRacket', 'MonsterSuit']
# `superhero` : ['PresidentSuperhero', 'CorporateSponsoredSuperhero', 'ProtoSuperhero', 'SuperheroTrophyShelf', 'SuperheroOrigin', 'MilitarySuperhero', 'CaptainSuperhero', 'SuperheroMovieVillainsDie', 'SuperheroPackingHeat', 'SuperheroSchool', 'OldSuperhero', 'SuperheroRegistrationAct', 'SuperheroParadox', 'DisposableSuperheroMaker', 'SuperheroSpeciation', 'SuperheroPrevalenceStages', 'TheAdjectivalSuperhero', 'Superhero']
# `crawling` : ['WallCrawling', 'DungeonCrawling']
# `apocalypse` : ['ApocalypseHow', 'ZombieApocalypse', 'ApocalypseCult', 'HorsemenOfTheApocalypse', 'NoBikesInTheApocalypse', 'MistakenForApocalypse', 'ApocalypseWow', 'UnspecifiedApocalypse', 'TheApocalypseBringsOutTheBestInPeople', 'ApocalypseAnarchy', 'ApocalypseHitler', 'VampireApocalypse', 'ApocalypseMaiden', 'SleptThroughTheApocalypse', 'DreamApocalypse', 'SugarApocalypse', 'StoryboardingTheApocalypse', 'ScrewTheRulesItsTheApocalypse']
# `geeks` : ['GiveGeeksAChance']
# `rapture` : ['CaughtUpInTheRapture']
# `spider` : ['SpiderMech', 'SpiderSwarm', 'FriendlyNeighborhoodSpider', 'GiantSpider', 'SpiderMan', 'SpiderLimbs', 'SpiderManSendUp', 'SpiderPeople', 'SpiderSense', 'SpiderTank', 'MoneySpider']
# `snakes` : ['SnakesAreSexy', 'SnakesAreEvil', 'SnakesAreSinister', 'WhyDidItHaveToBeSnakes']
# `souls` : ['LegionOfLostSouls', 'OurSoulsAreDifferent', 'StarsAreSouls', 'MergerOfSouls']
# `witches` : ['AllWitchesHaveCats']
# `malevolent` : ['MalevolentMaskedMan', 'MalevolentArchitecture', 'MalevolentMugshot', 'MalevolentMaskedMen']
# `bugs` : ['GoodBadBugs', 'FriendToBugs']
# `ghost` : ['GhostButler', 'VirtualGhost', 'FriendlyGhost', 'GhostPirate', 'BedsheetGhost', 'GhostTown', 'TheGhost', 'YouLookLikeYouveSeenAGhost', 'MayorOfAGhostTown', 'GhostStory', 'CuteGhostGirl', 'AnAstralProjectionNotAGhost', 'GhostMemory', 'GhostShip', 'GhostSong', 'GhostAmnesia', 'VengefulGhost', 'FirstPersonGhost', 'StringyHairedGhostGirl', 'ThrivingGhostTown', 'GhostInTheMachine', 'GhostExtras', 'GhostCity', 'GhostPlanet', 'GhostReunionEnding']
# `furry` : ['FurryReminder', 'FurryConfusion', 'FurryFemaleMane']
# `idiots` : ['SurroundedByIdiots', 'MooseAreIdiots']
# `nerds` : ['NerdsSpeakKlingon', 'NerdsAreVirgins', 'NerdsAreInnocent', 'GameOfNerds', 'NerdsAreSexy', 'NerdsLoveToughSchoolwork', 'EvenNerdsHaveStandards', 'NerdsLoveToughSchoolWork']
# `ninja` : ['SamuraiInNinjaTown', 'McNinja', 'Ninja', 'NinjaPirateZombieRobot', 'GratuitousNinja', 'HighlyVisibleNinja', 'NinjaPirateRobotZombie', 'InstantAwesomeJustAddNinja', 'NinjaSchool', 'NinjaProp', 'CatNinja', 'CyberNinja', 'TeenageMutantNinjaTurtles', 'InverseNinjaLaw', 'StockNinjaWeaponry']
# `autobots` : ['AutobotsRockOut']
# `sentient` : ['SentientPhlebotinum', 'SympatheticSentientWeapon', 'SentientCosmicForce', 'SentientVehicle']
# `misfits` : ['RagtagBandOfMisfits', 'RagtagBunchofMisfits', 'RagtagBunchOfMisfits', 'RagTagBunchOfMisfits']
# `beings` : ['TwoBeingsOneBody', 'EnergyBeings']
# `prey` : ['ThankYourPrey', 'NobleBirdOfPrey', 'KidnappingBirdOfPrey', 'MorePredatorsThanPrey']
# `alien` : ['InsufficientlyAdvancedAlien', 'DramaticAlienVTOL', 'BizarreAlienSenses', 'ImportedAlienPhlebotinum', 'AlienKudzu', 'PaletteSwappedAlienFood', 'AlienCatnip', 'RubberForeheadAlien', 'NoSuchThingAsAlienPopCulture', 'BizarreAlienLocomotion', 'HumansThroughAlienEyes', 'HumanOutsideAlienInside', 'AlienInvasion', 'AlienAbduction', 'AlienFairFolk', 'HordeOfAlienLocusts', 'StarfishAlien', 'AlienArtsAreAppreciated', 'HumanAlien', 'AlienBlood', 'FaceFullOfAlienWingWong', 'BizarreAlienBiology', 'IndoEuropeanAlienLanguage', 'AlienSky', 'TheDogIsAnAlien', 'InhumanableAlienRights', 'EasilyThwartedAlienInvasion', 'AutomobilesAreAlien', 'BenevolentAlienInvasion', 'AlienSpaceBats', 'AlienAnimals', 'BizarreAlienSexes', 'AmusingAlien', 'MechanisticAlienCulture', 'SufficientlyAdvancedAlien', 'HumanoidAlien', 'BizarreAlienReproduction', 'BizarreAlienPsychology', 'BeethovenWasAnAlienSpy', 'AlienGeometries', 'AlienLunch', 'AlienHair', 'AlienAmongUs', 'AlienNonInterferenceClause', 'StandardAlienSpaceship', 'AlienLandmass', 'AlienAutopsy']
# `awaken` : ['AwakenTheSleepingGiant', 'EyeAwaken']
# `ant` : ['AntWar']
# `mortal` : ['MortalWoundReveal', 'DoubleStandardRapeDivineOnMortal', 'IKnowMortalKombat']
# `creepy` : ['CreepyChangingPainting', 'CreepyCute', 'CreepyGood', 'CreepyRavens', 'CreepyCentipedes', 'CreepyFamily', 'CreepyCoolCrosses', 'CreepyBasement', 'CreepyCrossDresser', 'CreepyCrossdresser', 'CreepyCircusMusic', 'CreepyJazzMusic', 'UnnecessarilyCreepyRobot', 'CreepyLongFingers', 'CreepyGasStationAttendant', 'CreepyCathedral', 'CreepyOrderly', 'CreepyChild', 'CreepyCatholicism', 'CreepyCrows', 'CreepyDoll', 'SurpriseCreepy', 'CreepyShadowedUndereyes', 'CreepyMonotone', 'CreepyCockroach', 'CreepyHousekeeper', 'CreepyBlueEyes', 'CreepyCemetery', 'CreepySouvenir', 'CreepyMortician', 'CreepyPhysical', 'CreepyChildrenSinging', 'TaxidermyIsCreepy', 'CreepyTwins', 'CreepyLongArms', 'BigCreepyCrawlies', 'CreepyUncle']
# `avengers` : ['AvengersAssemble']
# `murderous` : ['MurderousMask', 'MurderousMannequin', 'MurderousThighs']
# `fairies` : ['OurFairiesAreDifferent']
# `primal` : ['PrimalFear', 'PrimalScene', 'PrimalStance', 'PrimalChestPound']
# `vigilante` : ['CopsNeedTheVigilante', 'VigilanteMan', 'VigilanteExecution']
# `robots` : ['NoisyRobots', 'RobotsEnslavingRobots', 'RidiculouslyHumanRobots', 'AmbiguousRobots', 'RaisedByRobots', 'SmartPeopleBuildRobots', 'StarfishRobots', 'DeceptivelyHumanRobots', 'RobotsThinkFaster']
# `halo` : ['HolyHalo', 'BackgroundHalo']
# `halloween` : ['ForHalloweenIAmGoingAsMyself', 'HalloweenSpecial', 'HalloweenTown']
# `rabbits` : ['LuckyRabbitsFoot']
# `invaders` : ['DemonicInvaders']
# `rodents` : ['RodentsOfUnusualSize']
# `henchmen` : ['HenchmenRace']
# `terminator` : ['DeTerminator', 'TerminatorTwosome']
# `unicorn` : ['Unicorn', 'DeadUnicornTrope']
# `supernatural` : ['SupernaturalFloatingHair', 'ClaimedByTheSupernatural', 'MarkedByTheSupernatural', 'SupernaturalRepellent', 'SupernaturalIsPurple', 'SupernaturalProofFather', 'SupernaturalGoldEyes', 'SupernaturalAngst', 'NeurodiversityIsSupernatural', 'ScrewTheRulesIHaveSupernaturalPowers', 'SupernaturalMartialArts', 'SupernaturalPhone', 'SupernaturalAid']
# `insects` : ['HumansAreInsects']
# `waking` : ['InstantWakingSkills', 'WakingNonSequitur', 'WakingUpElsewhere', 'WakingUpAtTheMorgue']
# `witch` : ['WitchWithACapitalB', 'GoodWitchVersusBadWitch', 'WitchHunter', 'BurnTheWitch', 'TheWitchHunter', 'SalemIsWitchCountry', 'WidowWitch', 'HotWitch', 'WitchSpecies', 'WitchHunt', 'WitchClassic', 'WickedWitch', 'WitchDoctor', 'CuteWitch']
# `spooky` : ['NunsAreSpooky', 'SpookySilentLibrary', 'SpookyPainting', 'SpookyPhotographs', 'SpookySeance']
# `devoured` : ['DevouredByTheHorde']
# `cats` : ['CatsAreMean', 'CatsAreSuperior', 'CatsAreMagic', 'AllWitchesHaveCats', 'CatsAreSnarkers', 'CatsHateWater', 'TheInternetIsForCats', 'CatsHaveNineLives']
# `turtles` : ['TeenageMutantNinjaTurtles']
# `aliens` : ['StarfishAliens', 'PlantAliens', 'InnocentAliens', 'AliensAreBastards', 'AliensStealCattle', 'AliensInCardiff', 'OctopoidAliens', 'AliensMadeThemDoIt', 'RubberForeheadAliens', 'AliensNeverInventedDemocracy', 'InvisibleAliens', 'AliensAndMonsters', 'ScaryDogmaticAliens', 'AbsentAliens', 'MistakenForAliens', 'HumanoidAliens', 'HumansNeedAliens', 'SufficientlyAdvancedAliens', 'InsectoidAliens', 'AliensSpeakingEnglish', 'DittoAliens', 'BarFullOfAliens', 'AliensStealCable', 'TranshumanAliens', 'IfJesusThenAliens', 'AliensOfLondon', 'InscrutableAliens', 'HumanAliens', 'AngelicAliens', 'StayWithTheAliens']
# `wandering` : ['WanderingJew', 'WanderingMinstrel']
# `clones` : ['FromClonesToGenre', 'SendInTheClones', 'ClonesArePeopleToo']
# `hideous` : ['HideousHangoverCure']
# `monstrous` : ['MonstrousSeal', 'EvilMakesYouMonstrous', 'MonstrousCannibalism', 'MonstrousHumanoid', 'MonstrousGerms']
# `menace` : ['MobileMenace', 'MenstrualMenace', 'MenaceDecay', 'MothMenace', 'ShearMenace']
# `wolverine` : ['WolverineClaws', 'WolverinePublicity']
# `kittens` : ['EverythingsCuterWithKittens']
# `hell` : ['WhatTheHellHero', 'FirstDayFromHell', 'ImGoingToHellForThis', 'HellOnEarth', 'SeeYouInHell', 'MarshmallowHell', 'HellGate', 'HellSeeker', 'EscapedFromHell', 'IronicHell', 'WhatTheHellAreYou', 'WarIsHell', 'HotAsHell', 'HellOfAHeaven', 'YouAreWorthHell', 'SophisticatedAsHell', 'BloodyBowelsOfHell', 'FireAndBrimstoneHell', 'WhereTheHellIsSpringfield', 'HellHotel', 'HellHolePrison', 'HomeMadeSweaterFromHell', 'ToHellAndBack', 'HellIsWar', 'BatOutOfHell', 'PutOnABusToHell', 'HellBentForLeather', 'WelcomeToHell', 'TrainingFromHell', 'HomemadeSweaterFromHell', 'EasyRoadToHell', 'Hell', 'WhatTheHellCostumingDepartment', 'PlatformHell', 'HellHound', 'DraggedOffToHell', 'HellYesMoment', 'BabysitterFromHell', 'DodgeBallIsHell', 'LegionsOfHell', 'DevelopmentHell', 'SelfInflictedHell', 'HellFollowsWithMe', 'HellIsThatNoise', 'DodgeballIsHell', 'GymClassHell', 'WhatTheHellIsThatAccent', 'AHellOfATime']
# `dungeon` : ['LockedInTheDungeon', 'DungeonBypass', 'DungeonMaster', 'EvidenceDungeon', 'DefinitelyFinalDungeon', 'DungeonBasedEconomy', 'DiscOneFinalDungeon', 'DungeonMastersGirlfriend', 'DungeonCrawling', 'TheVeryDefinitelyFinalDungeon']
# `imaginary` : ['ImaginaryEnemy', 'ImaginaryFriend', 'NotSoImaginaryFriend', 'ImaginaryLoveTriangle']
# `vengeful` : ['VengefulGhost', 'VengefulVendingMachine', 'VengefulWidow']
# `cyborg` : ['HollywoodCyborg', 'Cyborg']
# `elves` : ['CantArgueWithElves', 'SpaceElves', 'ElvesVsDwarves', 'ScrewYouElves', 'OurElvesAreBetter', 'ChristmasElves', 'OrcRaisedByElves']
# `crawl` : ['OpeningCrawl', 'Crawl', 'WallCrawl']
# `scavengers` : ['ScavengersAreScum', 'DisasterScavengers']
# `mayhem` : ['MacheteMayhem', 'MonowheelMayhem']
# `maniac` : ['ClothesMakeTheManiac', 'ManiacTongue', 'LovableSexManiac', 'LoveableSexManiac', 'BeetleManiac', 'PyroManiac', 'ManiacMonkeys', 'OmnicidalManiac']
# `vanish` : ['VehicleVanish']
# `sandman` : ['MisterSandmanSequence', 'TheSandman']
# `hulk` : ['HulkHogan', 'HulkOut', 'HulkSpeak']
# `scourge` : ['TheScourgeOfGod']
# `flesh` : ['JustAFleshWound', 'FleshVersusSteel', 'FleshGolem', 'StrongFleshWeakSteel', 'OnlyAFleshWound']
#
# enhancing search with : ['NaziZombies', 'RoomFullOfZombies', 'EverythingsDeaderWithZombies', 'OurZombiesAreDifferent', 'NoZombieCannibals', 'ZombieAdvocate', 'ZombieMooks', 'PlagueZombie', 'NinjaPirateZombieRobot', 'VoodooZombie', 'ArtificialZombie', 'NotAZombie', 'NinjaPirateRobotZombie', 'IncongruouslyDressedZombie', 'ZombieGait', 'TechnicallyLivingZombie', 'RevenantZombie', 'ZombieApocalypse', 'ZombiePukeAttack', 'ReviveKillsZombie', 'AndThenJohnWasAZombie', 'ZombieInfectee', 'AttractiveZombie', 'FriendlyZombie', 'FriendlyNeighborhoodVampires', 'VampiresSleepInCoffins', 'VampiresOwnNightclubs', 'VampiresHarem', 'YourVampiresSuck', 'VampiresAreRich', 'OurVampiresAreDifferent', 'VampiresOwnNightClubs', 'VampiresHateGarlic', 'VampiresAreSexGods', 'FriendlyNeighbourhoodVampires', 'UndeadAuthor', 'TheUndead', 'UndeadChild', 'TurnUndead', 'UndeadTaxExemption', 'MistakenForUndead', 'UndeadBarefooter', 'BurnTheUndead', 'SlidingScaleOfUndeadRegeneration', 'AliensAndMonsters', 'HunterOfMonsters', 'LetsMockTheMonsters', 'OurMonstersAreWeird', 'MonstersAnonymous', 'MonogenderMonsters', 'InvisibleMonsters', 'OurMonstersAreDifferent', 'TheManBehindTheMonsters', 'HumansAreTheRealMonsters', 'BenevolentMonsters', 'TeensAreMonsters', 'HeWhoFightsMonsters', 'MonstersFavoritePettingSpot', 'WhisperingGhosts', 'OurGhostsAreDifferent', 'BewareOfHitchhikingGhosts', 'SuperheroesWearTights', 'OurAncestorsAreSuperheroes', 'MovieSuperheroesWearBlack', 'AnimalSuperheroes', 'SuperheroesWearCapes', 'RadiationImmuneMutants', 'Mutants', 'DivinelyAppearingDemons', 'OurDemonsAreDifferent', 'HornyDemons', 'BusesAreForFreaks', 'LonersAreFreaks', 'CockroachesWillRuleTheEarth', 'MusicSoothesTheSavageBeast', 'BeastMan', 'BeastOfBattle', 'BlindAndTheBeast', 'NumberOfTheBeast', 'FedToTheBeast', 'BeastAndBeauty', 'BeautyToBeast', 'BeastFable', 'MarkOfTheBeast', 'ResistTheBeast', 'DireBeast', 'YouSexyBeast', 'TheBeastMaster', 'MultipleTailedBeast', 'BeastWithAHumanFace', 'BondCreatures', 'WoodlandCreatures', 'DisneyCreaturesOfTheFarce', 'DevourTheDragon', 'KingOfBeasts', 'PunchClockVillains', 'MakeWayForTheNewVillains', 'SensibleHeroesSkimpyVillains', 'HeroesActVillainsHinder', 'SuperHeroMovieVillainsDie', 'VillainsActHeroesReact']
#
# tropes used for final query : ['NaziZombies', 'RoomFullOfZombies', 'EverythingsDeaderWithZombies', 'OurZombiesAreDifferent', 'NoZombieCannibals', 'ZombieAdvocate', 'ZombieMooks', 'PlagueZombie', 'NinjaPirateZombieRobot', 'VoodooZombie', 'ArtificialZombie', 'NotAZombie', 'NinjaPirateRobotZombie', 'IncongruouslyDressedZombie', 'ZombieGait', 'TechnicallyLivingZombie', 'RevenantZombie', 'ZombieApocalypse', 'ZombiePukeAttack', 'ReviveKillsZombie', 'AndThenJohnWasAZombie', 'ZombieInfectee', 'AttractiveZombie', 'FriendlyZombie', 'FriendlyNeighborhoodVampires', 'VampiresSleepInCoffins', 'VampiresOwnNightclubs', 'VampiresHarem', 'YourVampiresSuck', 'VampiresAreRich', 'OurVampiresAreDifferent', 'VampiresOwnNightClubs', 'VampiresHateGarlic', 'VampiresAreSexGods', 'FriendlyNeighbourhoodVampires', 'UndeadAuthor', 'TheUndead', 'UndeadChild', 'TurnUndead', 'UndeadTaxExemption', 'MistakenForUndead', 'UndeadBarefooter', 'BurnTheUndead', 'SlidingScaleOfUndeadRegeneration', 'AliensAndMonsters', 'HunterOfMonsters', 'LetsMockTheMonsters', 'OurMonstersAreWeird', 'MonstersAnonymous', 'MonogenderMonsters', 'InvisibleMonsters', 'OurMonstersAreDifferent', 'TheManBehindTheMonsters', 'HumansAreTheRealMonsters', 'BenevolentMonsters', 'TeensAreMonsters', 'HeWhoFightsMonsters', 'MonstersFavoritePettingSpot', 'WhisperingGhosts', 'OurGhostsAreDifferent', 'BewareOfHitchhikingGhosts', 'SuperheroesWearTights', 'OurAncestorsAreSuperheroes', 'MovieSuperheroesWearBlack', 'AnimalSuperheroes', 'SuperheroesWearCapes', 'RadiationImmuneMutants', 'Mutants', 'DivinelyAppearingDemons', 'OurDemonsAreDifferent', 'HornyDemons', 'BusesAreForFreaks', 'LonersAreFreaks', 'CockroachesWillRuleTheEarth', 'MusicSoothesTheSavageBeast', 'BeastMan', 'BeastOfBattle', 'BlindAndTheBeast', 'NumberOfTheBeast', 'FedToTheBeast', 'BeastAndBeauty', 'BeautyToBeast', 'BeastFable', 'MarkOfTheBeast', 'ResistTheBeast', 'DireBeast', 'YouSexyBeast', 'TheBeastMaster', 'MultipleTailedBeast', 'BeastWithAHumanFace', 'BondCreatures', 'WoodlandCreatures', 'DisneyCreaturesOfTheFarce', 'DevourTheDragon', 'KingOfBeasts', 'PunchClockVillains', 'MakeWayForTheNewVillains', 'SensibleHeroesSkimpyVillains', 'HeroesActVillainsHinder', 'SuperHeroMovieVillainsDie', 'VillainsActHeroesReact', 'DoesThisRemindYouOfAnything', 'ForebodingFleeingFlock', 'ParentalBonus', 'MaliciousSlander', 'ForgottenPhlebotinum', 'WordOfGod', 'BecomingTheBoast', 'StealingTheCredit', 'EpicFail', 'CoolAndUnusualPunishment', 'EarlyBirdCameo', 'OurBugbearsAreScarier', 'Diary', 'RansackedRoom', 'BlankBook', 'FlyingCar', 'ContrivedCoincidence', 'Narm', 'ButtDialingMordor', 'HearingVoices', 'WhatMeasureIsANonHuman', 'EnslavedTongue', 'NotMeThisTime', 'INeverSaidItWasPoison', 'SpiderSwarm', 'Narcissist', 'RedHerring', 'BeastInTheMaze', 'DudeNotFunny', 'BigBrotherInstinct', 'ComicallyIneptHealing', 'HandOfGlory', 'IThoughtEveryoneCouldDoThat', 'BreakTheHaughty', 'BalefulPolymorph', 'ObliviousGuiltSlinging', 'MrFanservice', 'AllForNothing', 'HijackedByGanon', 'OhCrap', 'ThoroughlyMistakenIdentity', 'TheAllegedExpert', 'MonsterOfTheWeek', 'MilkyWhiteEyes', 'StarstruckSpeechless', 'StrongerWithAge', 'LaserGuidedKarma', 'WritersCannotDoMath', 'MindRape', 'LittleNo', 'DisproportionateRetribution', 'BuffySpeak', 'SneezeOfDoom', 'ThisIsGonnaSuck', 'BatScare', 'InvisibleWriting', 'InnocuouslyImportantEpisode', 'LovePotion', 'VillainWithGoodPublicity', 'MuggleBornOfMages', 'WreckedWeapon', 'CallingOutForNotCalling', 'ThirdPersonPerson', 'TheReasonYouSuckSpeech', 'WhoWouldBeStupidEnough', 'ChekhovsGunman', 'LetMeAtHim', 'MagicMisfire', 'CaughtWithYourPantsDown', 'OrificeEvacuation', 'TheDandy', 'DeadlyBook', 'HilarityEnsues', 'SentientVehicle', 'HorrorDoesntSettleForSimpleTuesday', 'TrickedIntoSigning', 'EverybodyLives', 'HoistByHisOwnPetard', 'SignificantAnagram', 'NoodleIncident', 'RuleOfThree', 'ObfuscatingStupidity', 'JerkassHasAPoint', 'IJustWantToBeFree', 'SoulJar', 'AbsurdlySpaciousSewer', 'RewatchBonus', 'WroteTheBook', 'TomTheDarkLord', 'ShrineToSelf',  ...
#
# top 10 most similar titles to `Harry Potter and the Chamber of Secrets` by trope to keyword `zombies`
# (0.08369346296290862, 'What We Do in the Shadows')
# (0.07122098095865849, 'Day of the Dead')
# (0.0656970020597901, 'ParaNorman')
# (0.060317136682517224, 'Shaun of the Dead')
# (0.06016242255245239, 'Arachnophobia')
# (0.058643858806923785, 'How to Train Your Dragon')
# (0.058627864030753776, 'Cemetery Man')
# (0.058519893052519, 'Dèmoni')
# (0.05747622878640979, 'Monsters, Inc.')
# (0.056671380151352604, 'Hotel Transylvania')
